# %%
import pandas as pd

# %%
ufo=pd.read_csv('Bangalore_schools.csv',delimiter="|")

# %%
ufo.loc[ufo.pincode=="560062",["schoolname","area","pincode"]]
# Out:
#                             schoolname  \
# 0                       GKHPS ALAHALLI
# 28                  GKHPS BANJARAPALYA
# 166   GKLPS LAKSHMIPURA (VAJARA HALLI)
# 185             GKHPS NAGEGOWDANAPALYA
# 186                  GKLPS RACHANAMADU
# 191            GKHPS DODDA KALLASANDRA
# 348          GKLPS CHIKKEGOWDANA PALYA
# 470   GKLPS VADERAHALLI (VAJARA HALLI)
# 474                  GKMPS KONANAKUNTE
# 623                  GKHPS VAJARAHALLI
# 624                        GKHPS AGARA
# 629                   GKMPS ANJANAPURA
# 634                  GKLPS TIPPASANDRA
# 635                   GKLPS TULASIPURA
# 656                     GUHPS ALAHALLI
# 871                GKHPS GANIGARAPALYA
# 872                    GKHPS THATAGUNI
# 1013               GKMPS TALAGATTAPURA
# 1217            GKLPS RAJIVGANDHINAGAR
# 1218        GULPS MAHATHMAGANDHINAGARA
# 1376                GKHPS CHUNCHAGATTA
#
#                                          area pincode
# ...

# %%
ufo.columns
# Out:
# Index([' district', 'block', 'cluster', 'schoolid', 'schoolname', 'category',
#        'gender', 'medium_of_inst', 'address', 'area', 'pincode', 'landmark',
#        'busroutes'],
#       dtype='object')

# %%
ufo.loc[(ufo.pincode=="bangalore") | (ufo.schoolname=="bangalore") | (ufo.address=="bangalore") | (ufo.area=="bangalore") | (ufo.landmark=="bangalore"),["schoolname","area","pincode"]]
# Out:
#                              schoolname       area pincode
# 0                        GKHPS ALAHALLI  bangalore  560062
# 2                    GKHPS SRIKANTAPURA  bangalore  560073
# 3                        GTHPS BELIMUTT  bangalore  560053
# 95                     GKLPS ASHOKNAGAR  bangalore  560025
# 103          GKMPS AGRAHARA DASARAHALLI  bangalore  560079
# 104                    GKHPS NARASAPURA  bangalore  562107
# 235                    GUHPBS JJR NAGAR  bangalore  560018
# 237               GULPS PAILVANARAPALYA  bangalore  560058
# 238                  GKHPS YARENDAHALLI  bangalore  999999
# 239                         GKMPS AGARA  bangalore  560102
# 240                    GKLPS KUDUREGERE  bangalore  562157
# 372         GKLPS GUDDADAHALLI (HEBBAL)  bangalore  560032
# 373                 GULPS JAKKUR LAYOUT  bangalore  560064
# 374             GKHPS HUNASEMARENAHALLI  bangalore  562157
# 375         GKHPS 4TH T BLOCK JAYANAGAR  bangalore  560041
# ...
